# %% [markdown]
# 필수알고리즘with파이썬_6
# ============

# %% [markdown]
# # LESSON 06 트리(Tree)
#
# 6.1 트리(Tree)의 개념과 용어
# 6.2 이진 트리(Binary Tree)
# 6.3 정리

# %% [markdown]
# ## 6.1 트리(Tree)의 개념과 용어
# - 트리는 노드와 링크를 이용한 자료구조이다.
#
# 6.1.1 트리 구조
# ![%ED%8A%B8%EB%A6%AC%EA%B5%AC%EC%A1%B0.png](attachment:%ED%8A%B8%EB%A6%AC%EA%B5%AC%EC%A1%B0.png)
# - 용어 정리: 루트 노드, 부모 노드, 자식 노드, 리프 노드, 형제 노드
# 노드의 레벨, 트리의 높이
# - 트리를 __재귀적인 표현으로 정의__하면 다음과 같은 성질을 갖는다.
#
#
# 1. 트리에는 루트 노드가 반드시 존재한다.
# 2. 루트 노드를 제외한 나머지 노드들은 여러 개의 노드들의 그룹으로 나뉠 수 있으며 그 노드 그룹 역시 하나의 트리가 된다.
#
#
# 6.1.2 트리의 용어
# 1. 차수: 한 노드에 연결된 서브 트리의 __개수__. 차수가 2개 이하의 트리 구조를 특별히 이진 트리(Binary Tree)라고 한다.

# %% [markdown]
# ## 6.2 이진 트리(Binary Tree)
# - 트리의 차수가 2 이하인 트리를 이진 트리라고 한다.
# 6.2.1 이진 트리의 구조와 특성
# ![%ED%8A%B8%EB%A6%AC%EA%B5%AC%EC%A1%B0.png](attachment:%ED%8A%B8%EB%A6%AC%EA%B5%AC%EC%A1%B0.png)
# - 이진 트리는 자식 노드가 2개만 존재하기 때문에 구현이 간단하다.
#
#
# 6.2.2 이진 트리의 종류
# 1. 정 이진 트리(full binary tree)
# 단말 노드가 아닌 모든 노드가 2개의 자식을 가진 트리
# 2. 포화 이진 트리(perfect binary tree)
# 모든 단말 노드의 깊이가 같은 정 이진 트리
# 3. 완전 이진 트리(complete binary tree)
# 끝 부분을 제외하고 모든 노드가 채워진 이진 트리![%EC%9D%B4%EC%A7%84%20%ED%8A%B8%EB%A6%AC%EC%9D%98%20%EC%A2%85%EB%A5%98.png](attachment:%EC%9D%B4%EC%A7%84%20%ED%8A%B8%EB%A6%AC%EC%9D%98%20%EC%A2%85%EB%A5%98.png)
# 4. 균형 이진 트리(balanced binary tree)
# 모든 단말 노드의 깊이 차이가 많아야 1인 트리
# ![balanced%20binary%20tree.png](attachment:balanced%20binary%20tree.png)
#
# 5. 변질 트리(degenerate tree)
# 각각의 부모 노드가 하나의 자식만을 갖는 트리
# ![degenerate%20tree.png](attachment:degenerate%20tree.png)

# %% [markdown]
# ## 6.3 정리
#
# 트리 구조에서 사용하는 여러 가지 용어들에 대해 익숙해지는 것이 좋다. 이진 트리의 순회 알고리즘에 대해서는 다음 Lesson에서 자세히 알아보자
